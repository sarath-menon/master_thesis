# %%
from datasets import load_dataset
import numpy as np

# %%
dataset = load_dataset("Bingsu/Gameplay_Images")
# Out:
# Downloading readme: 100%|██████████| 2.91k/2.91k [00:00<00:00, 13.3MB/s]
# Downloading metadata: 100%|██████████| 1.62k/1.62k [00:00<00:00, 9.47MB/s]
# Downloading data: 100%|██████████| 653M/653M [00:43<00:00, 15.1MB/s]
# Downloading data: 100%|██████████| 723M/723M [00:42<00:00, 17.0MB/s]
# Downloading data: 100%|██████████| 772M/772M [00:43<00:00, 17.9MB/s]
# Downloading data: 100%|██████████| 541M/541M [00:34<00:00, 15.7MB/s]
# Generating train split: 100%|██████████| 10000/10000 [00:03<00:00, 2529.46 examples/s]

# %%
class_labels = dataset["train"].features["label"].names
class_id = 2
index = class_id * 1000 + np.random.randint(0, 999)

print(class_labels[dataset["train"][index]["label"]])
dataset["train"][index]["image"]
# Out:
# Fortnite
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x360>
